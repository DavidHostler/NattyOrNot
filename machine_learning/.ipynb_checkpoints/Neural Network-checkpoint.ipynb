# %%
import tensorflow as tf
import numpy as np
from tensorflow import keras
import os
import cv2
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing import image
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import(Dense, Dropout, Activation, Flatten)
from tensorflow.keras.layers import Conv2D, MaxPooling2D
import matplotlib.pyplot as plt
# Out:
# /usr/lib/python3/dist-packages/requests/__init__.py:89: RequestsDependencyWarning: urllib3 (1.26.8) or chardet (3.0.4) doesn't match a supported version!
#   warnings.warn("urllib3 ({}) or chardet ({}) doesn't match a supported "

# %%
path = os.listdir("/media/dolan/Backup Plus/Physiques")
len(path)
# Out:
# 210

# %%
class Data:
    
    def __init__(self):
        self.bodybuilders = []
        self.natties = []
        self.training_data = []
        self.test_data = []
        self.path = "/media/dolan/Backup Plus/"
        self.IMG_SIZE = 125
    
    def generate(self, string): #string === pathnameend
        path = os.path.join(self.path, string)
        if string == 'Bodybuilders':
            class_num = 1
        elif string == 'Natty':
            class_num = 0
        else:
            return
        counter = 0
        for img in os.listdir(path):
            if class_num == 1:
                try:
                    img_array = cv2.imread(os.path.join(path,img), cv2.IMREAD_GRAYSCALE)
                    new_array = cv2.resize(img_array, (self.IMG_SIZE,self.IMG_SIZE))
                    self.bodybuilders.append([new_array,class_num])
                except Exception as e:
                    pass     
            elif class_num == 0:
                try:
                    img_array = cv2.imread(os.path.join(path,img), cv2.IMREAD_GRAYSCALE)
                    new_array = cv2.resize(img_array, (self.IMG_SIZE,self.IMG_SIZE))
                    self.natties.append([new_array,class_num])
                except Exception as e:
                    pass   
            else:
                print("Classnum is not valid friend")
                
            counter += 1
            
            print("Image resized: ", counter)

# %%
data = Data()
data.generate('Bodybuilders')
data.generate('Natty')
# Out:
# Image resized:  1
# Image resized:  2
# Image resized:  3
# Image resized:  4
# Image resized:  5
# Image resized:  6
# Image resized:  7
# Image resized:  8
# Image resized:  9
# Image resized:  10
# Image resized:  11
# Image resized:  12
# Image resized:  13
# Image resized:  14
# Image resized:  15
# Image resized:  16
# Image resized:  17
# Image resized:  18
# Image resized:  19
# Image resized:  20
# Image resized:  21
# Image resized:  22
# Image resized:  23
# Image resized:  24
# Image resized:  25
# Image resized:  26
# Image resized:  27
# Image resized:  28
# Image resized:  29
# Image resized:  30
# Image resized:  31
# Image resized:  32
# Image resized:  33
# Image resized:  34
# Image resized:  35
# Image resized:  36
# Image resized:  37
# Image resized:  38
# Image resized:  39
# Image resized:  40
# Image resized:  41
# Image resized:  42
# Image resized:  43
# Image resized:  44
# Image resized:  45
# Image resized:  46
# Image resized:  47
# Image resized:  48
# Image resized:  49
# Image resized:  50
# Image resized:  51
# Image resized:  52
# Image resized:  53
# Image resized:  54
# Image resized:  55
# Image resized:  56
# Image resized:  57
# Image resized:  58
# Image resized:  59
# Image resized:  60
# Image resized:  61
# Image resized:  62
# Image resized:  63
# Image resized:  64
# Image resized:  65
# Image resized:  66
# Image resized:  67
# Image resized:  68
# Image resized:  69
# Image resized:  70
# Image resized:  71
# Image resized:  72
# Image resized:  73
# Image resized:  74
# Image resized:  75
# Image resized:  76
# Image resized:  77
# Image resized:  78
# Image resized:  79
# Image resized:  80
# Image resized:  81
# Image resized:  82
# Image resized:  83
# Image resized:  84
# Image resized:  85
# Image resized:  86
# Image resized:  87
# Image resized:  88
# Image resized:  89
# Image resized:  90
# Image resized:  91
# Image resized:  92
# Image resized:  93
# Image resized:  94
# Image resized:  95
# Image resized:  96
# Image resized:  97
# Image resized:  98
# Image resized:  99
# Image resized:  100
# Image resized:  101
# Image resized:  102
# Image resized:  103
# Image resized:  104
# Image resized:  105
# Image resized:  106
# Image resized:  107
# Image resized:  108
# Image resized:  109
# Image resized:  110
# Image resized:  111
# Image resized:  112
# Image resized:  113
# Image resized:  114
# Image resized:  115
# Image resized:  116
# Image resized:  117
# Image resized:  118
# Image resized:  119
# Image resized:  120
# Image resized:  121
# Image resized:  122
# Image resized:  123
# Image resized:  124
# Image resized:  125
# Image resized:  126
# Image resized:  127
# Image resized:  128
# Image resized:  129
# Image resized:  130
# Image resized:  131
# Image resized:  132
# Image resized:  133
# Image resized:  134
# Image resized:  135
# Image resized:  136
# Image resized:  137
# Image resized:  138
# Image resized:  139
# Image resized:  140
# Image resized:  141
# Image resized:  142
# Image resized:  143
# Image resized:  144
# Image resized:  145
# Image resized:  146
# Image resized:  147
# Image resized:  148
# Image resized:  149
# Image resized:  150
# Image resized:  151
# Image resized:  152
# Image resized:  153
# Image resized:  154
# Image resized:  155
# Image resized:  156
# Image resized:  157
# Image resized:  158
# Image resized:  159
# Image resized:  160
# Image resized:  161
# Image resized:  162
# Image resized:  163
# Image resized:  164
# Image resized:  165
# Image resized:  166
# Image resized:  167
# Image resized:  168
# Image resized:  169
# Image resized:  170
# Image resized:  171
# Image resized:  172
# Image resized:  173
# Image resized:  174
# Image resized:  175
# Image resized:  176
# Image resized:  177
# Image resized:  178
# Image resized:  179
# Image resized:  180
# Image resized:  181
# Image resized:  182
# Image resized:  183
# Image resized:  184
# Image resized:  185
# Image resized:  186
# Image resized:  187
# Image resized:  188
# Image resized:  189
# Image resized:  190
# Image resized:  191
# Image resized:  192
# Image resized:  193
# Image resized:  194
# Image resized:  195
# Image resized:  196
# Image resized:  197
# Image resized:  198
# Image resized:  199
# Image resized:  200
# Image resized:  201
# Image resized:  202
# Image resized:  203
# Image resized:  204
# Image resized:  205
# Image resized:  206
# Image resized:  207
# Image resized:  208
# Image resized:  209
# Image resized:  210
# Image resized:  1
# Image resized:  2
# Image resized:  3
# Image resized:  4
# Image resized:  5
# Image resized:  6
# Image resized:  7
# Image resized:  8
# Image resized:  9
# Image resized:  10
# Image resized:  11
# Image resized:  12
# Image resized:  13
# Image resized:  14
# Image resized:  15
# Image resized:  16
# Image resized:  17
# Image resized:  18
# Image resized:  19
# Image resized:  20
# Image resized:  21
# Image resized:  22
# Image resized:  23
# Image resized:  24
# Image resized:  25
# Image resized:  26
# Image resized:  27
# Image resized:  28
# Image resized:  29
# Image resized:  30
# Image resized:  31
# Image resized:  32
# Image resized:  33
# Image resized:  34
# Image resized:  35
# Image resized:  36
# Image resized:  37
# Image resized:  38
# Image resized:  39
# Image resized:  40
# Image resized:  41
# Image resized:  42
# Image resized:  43
# Image resized:  44
# Image resized:  45
# Image resized:  46
# Image resized:  47
# Image resized:  48
# Image resized:  49
# Image resized:  50
# Image resized:  51
# Image resized:  52
# Image resized:  53
# Image resized:  54
# Image resized:  55
# Image resized:  56
# Image resized:  57
# Image resized:  58
# Image resized:  59
# Image resized:  60
# Image resized:  61
# Image resized:  62
# Image resized:  63
# Image resized:  64
# Image resized:  65
# Image resized:  66
# Image resized:  67
# Image resized:  68
# Image resized:  69
# Image resized:  70
# Image resized:  71
# Image resized:  72
# Image resized:  73
# Image resized:  74
# Image resized:  75
# Image resized:  76
# Image resized:  77
# Image resized:  78
# Image resized:  79
# Image resized:  80
# Image resized:  81
# Image resized:  82
# Image resized:  83
# Image resized:  84
# Image resized:  85
# Image resized:  86
# Image resized:  87
# Image resized:  88
# Image resized:  89
# Image resized:  90
# Image resized:  91
# Image resized:  92
# Image resized:  93
# Image resized:  94
# Image resized:  95
# Image resized:  96
# Image resized:  97
# Image resized:  98
# Image resized:  99
# Image resized:  100
# Image resized:  101
# Image resized:  102
# Image resized:  103
# Image resized:  104
# Image resized:  105
# Image resized:  106
# Image resized:  107
# Image resized:  108
# Image resized:  109
# Image resized:  110
# Image resized:  111
# Image resized:  112
# Image resized:  113
# Image resized:  114
# Image resized:  115
# Image resized:  116
# Image resized:  117
# Image resized:  118
# Image resized:  119
# Image resized:  120
# Image resized:  121
# Image resized:  122
# Image resized:  123
# Image resized:  124
# Image resized:  125
# Image resized:  126
# Image resized:  127
# Image resized:  128
# Image resized:  129
# Image resized:  130
# Image resized:  131
# Image resized:  132
# Image resized:  133
# Image resized:  134
# Image resized:  135
# Image resized:  136
# Image resized:  137
# Image resized:  138
# Image resized:  139
# Image resized:  140
# Image resized:  141
# Image resized:  142
# Image resized:  143
# Image resized:  144
# Image resized:  145
# Image resized:  146
# Image resized:  147
# Image resized:  148
# Image resized:  149
# Image resized:  150
# Image resized:  151
# Image resized:  152
# Image resized:  153
# Image resized:  154
# Image resized:  155
# Image resized:  156
# Image resized:  157
# Image resized:  158
# Image resized:  159
# Image resized:  160
# Image resized:  161
# Image resized:  162
# Image resized:  163
# Image resized:  164
# Image resized:  165
# Image resized:  166
# Image resized:  167
# Image resized:  168
# Image resized:  169
# Image resized:  170
# Image resized:  171
# Image resized:  172
# Image resized:  173
# Image resized:  174
# Image resized:  175
# Image resized:  176
# Image resized:  177
# Image resized:  178
# Image resized:  179
# Image resized:  180
# Image resized:  181
# Image resized:  182
# Image resized:  183
# Image resized:  184
# Image resized:  185
# Image resized:  186
# Image resized:  187
# Image resized:  188
# Image resized:  189
# Image resized:  190
# Image resized:  191
# Image resized:  192
# Image resized:  193
# Image resized:  194
# Image resized:  195
# Image resized:  196
# Image resized:  197
# Image resized:  198
# Image resized:  199
# Image resized:  200
# Image resized:  201
# Image resized:  202
# Image resized:  203
# Image resized:  204
# Image resized:  205
# Image resized:  206
# Image resized:  207
# Image resized:  208
# Image resized:  209
# Image resized:  210

# %%
print(len(data.bodybuilders), len(data.natties))
# Out:
# 210 210

# %%
#Shuffle the data
import random

data_ = data.bodybuilders + data.natties
print(len(data_))

random.shuffle(data_)

0.25 * len(data_),0.75 * len(data_)
# Out:
# 420
# (105.0, 315.0)

# %%
def generate_inputs(dataset):
    X = []
    y = []
    for i in range(len(dataset)):
        X.append(dataset[i][0])
        y.append(dataset[i][1])
        
    return X,y
        

training_data = data_[:315]
test_data = data_[315:]    
    
X_train, y_train = generate_inputs(training_data)
X_test, y_test = generate_inputs(test_data)
X, y = generate_inputs(data_)

# %%
len(X_train), len(y_test)
# Out:
# (315, 105)

# %%
.plt.imshow(X_train[5])

# %%
#Develop valid dataset by normalizing image arrays`

IMG_SIZE = data.IMG_SIZE
X_train = np.array(X_train).reshape(-1, IMG_SIZE, IMG_SIZE,1)
X_test = np.array(X_test).reshape(-1, IMG_SIZE, IMG_SIZE,1) 
X = np.array(X).reshape(-1, IMG_SIZE, IMG_SIZE, 1)
X_train = X_train/255.0
X_test = X_test/255.0
X = X/255.0

y = np.array(y)

# %%
y.shape, X.shape
# Out:
# ((420,), (420, 125, 125, 1))

# %%
model = Sequential()
model.add(Conv2D(256, (3, 3), input_shape=X.shape[1:]))
model.add(Activation('relu'))
model.add(Dropout(0.2))
model.add(MaxPooling2D(pool_size=(3, 3)))

model.add(Conv2D(256, (3, 3)))
model.add(Activation('relu'))
model.add(Dropout(0.2))
model.add(MaxPooling2D(pool_size=(3, 3)))


model.add(Conv2D(256, (3, 3)))
model.add(Activation('relu'))
model.add(Dropout(0.2))
model.add(MaxPooling2D(pool_size=(3, 3)))

model.add(Flatten())  # this converts our 3D feature maps to 1D feature vectors

model.add(Dense(64))

model.add(Dense(1))
model.add(Activation('sigmoid'))

# %%
model.compile(loss='binary_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

model.fit(X, y,  batch_size = 10, epochs = 10, validation_split = 0.25)
# Out:
# Epoch 1/10
# 32/32 [==============================] - 56s 2s/step - loss: 0.7330 - accuracy: 0.5651 - val_loss: 0.6223 - val_accuracy: 0.6667
# Epoch 2/10
# 32/32 [==============================] - 71s 2s/step - loss: 0.6476 - accuracy: 0.6857 - val_loss: 0.6564 - val_accuracy: 0.6286
# Epoch 3/10
# 32/32 [==============================] - 90s 3s/step - loss: 0.5699 - accuracy: 0.7048 - val_loss: 0.5995 - val_accuracy: 0.6762
# Epoch 4/10
# 32/32 [==============================] - 83s 3s/step - loss: 0.5249 - accuracy: 0.7333 - val_loss: 0.5765 - val_accuracy: 0.7333
# Epoch 5/10
# 32/32 [==============================] - 83s 3s/step - loss: 0.4596 - accuracy: 0.7873 - val_loss: 0.5303 - val_accuracy: 0.7143
# Epoch 6/10
# 32/32 [==============================] - 89s 3s/step - loss: 0.5331 - accuracy: 0.7746 - val_loss: 0.5820 - val_accuracy: 0.7238
# Epoch 7/10
# 32/32 [==============================] - 83s 3s/step - loss: 0.4113 - accuracy: 0.8222 - val_loss: 0.5466 - val_accuracy: 0.7714
# Epoch 8/10
# 32/32 [==============================] - 85s 3s/step - loss: 0.4167 - accuracy: 0.8190 - val_loss: 0.5425 - val_accuracy: 0.7619
# Epoch 9/10
# 32/32 [==============================] - 103s 3s/step - loss: 0.3085 - accuracy: 0.8571 - val_loss: 0.5150 - val_accuracy: 0.7714
# Epoch 10/10
# 32/32 [==============================] - 86s 3s/step - loss: 0.2518 - accuracy: 0.8889 - val_loss: 0.4948 - val_accuracy: 0.7905

# %%
#Predict whether the image is of a dog or of a cat!!!

def predict(data):
    if data.shape == (len(data), IMG_SIZE, IMG_SIZE, 1):
        preds = model.predict(data).tolist()
        
        for i in range(len(preds)):
            if preds[i][0] >= 0.5:
                preds[i] = 'Not'
            elif preds[i][0] < 0.5:
                preds[i] = 'Natty'
        
        return preds
    elif data.shape == (IMG_SIZE, IMG_SIZE, 1):
        data = np.expand_dims(data, axis = 0)
        pred = model.predict(data)
        if pred >= 0.5:
            pred = 'Not'
        else:
            pred = 'Natty'
            
        return pred
    
    else:
        return

# %%
predict(X_train[8])
# Out:
# 'Not'

# %%
plt.imshow(X_train[8])

# %%
plt.imshow(X_train[8]), preds[8]
# Out:
# (<matplotlib.image.AxesImage at 0x7f0cc40825b0>,
#  array([0.7945347], dtype=float32))

# %%
preds = model.predict(X_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-0aea73f09818> in <module>
# ----> 1 preds = model.predict(X_train)
#
# NameError: name 'model' is not defined

# %%
plt.imshow(X_train[2]), preds[2]
# Out:
# (<matplotlib.image.AxesImage at 0x7f0cc41a4d30>,
#  array([0.89360917], dtype=float32))

# %%
plt.imshow(X_train[1]), preds[1]
# Out:
# (<matplotlib.image.AxesImage at 0x7f0cc406e1c0>,
#  array([0.36544347], dtype=float32))

# %% [markdown]
# # Save The Model

# %%
model.save("nattyornot.h5")

# %% [markdown]
# ### Generate Stack to List Most recent Image

# %%
path = '/home/dolan/Downloads/NattyOrNot/backend/media/images'
#len(path)

def generate(string): #string === pathnameend
    path = '/home/dolan/Downloads/NattyOrNot/backend/media/images/'
    path = os.path.join(path, string)
    IMG_SIZE = 125
    
    counter = 0
    
    arr = []
    
    try:
        img_array = cv2.imread(path, cv2.IMREAD_GRAYSCALE)
        new_array = cv2.resize(img_array, (IMG_SIZE,IMG_SIZE))
        #arr.append([new_array,class_num])
    except Exception as e:
        pass     



        counter += 1

        print("Image resized: ", counter)
    return new_array


images_path = os.listdir('/home/dolan/Downloads/NattyOrNot/backend/media/images')
most_recent_upload = images_path.pop(0)
print(most_recent_upload)
# Out:
# download.jpeg

# %%
img_array = generate(most_recent_upload)
img_array
# Out:
# array([[51, 53, 57, ..., 82, 81, 81],
#        [87, 82, 70, ..., 77, 84, 82],
#        [75, 77, 73, ..., 88, 90, 84],
#        ...,
#        [43, 43, 43, ..., 65, 65, 66],
#        [45, 45, 45, ..., 66, 66, 66],
#        [45, 45, 45, ..., 67, 66, 66]], dtype=uint8)

# %%
#Convert to numpy array in order to feed data to neural network
IMG_SIZE = 125
img_array_ = np.array(img_array).reshape(-1, IMG_SIZE, IMG_SIZE, 1)
img_array_ = img_array_/255.0

# %%
img_array.shape, img_array_.shape, img_array_
# Out:
# ((125, 125),
#  (1, 125, 125, 1),
#  array([[[[0.2       ],
#           [0.20784314],
#           [0.22352941],
#           ...,
#           [0.32156863],
#           [0.31764706],
#           [0.31764706]],
#
#          [[0.34117647],
#           [0.32156863],
#           [0.2745098 ],
#           ...,
#           [0.30196078],
#           [0.32941176],
#           [0.32156863]],
#
#          [[0.29411765],
#           [0.30196078],
#           [0.28627451],
#           ...,
#           [0.34509804],
#           [0.35294118],
#           [0.32941176]],
#
#          ...,
#
#          [[0.16862745],
#           [0.16862745],
#           [0.16862745],
#           ...,
#           [0.25490196],
#           [0.25490196],
#           [0.25882353]],
#
#          [[0.17647059],
#           [0.17647059],
#           [0.17647059],
#           ...,
#           [0.25882353],
#           [0.25882353],
#           [0.25882353]],
#
#          [[0.17647059],
#           [0.17647059],
#           [0.17647059],
#           ...,
#           [0.2627451 ],
#           [0.25882353],
#           [0.25882353]]]]))

# %%
model.predict(img_array_)
# Out:
# array([[0.3510737]], dtype=float32)

# %%
plt.imshow(img_array), model.predict(img_array_)
# Out:
# (<matplotlib.image.AxesImage at 0x7f0c9e605df0>,
#  array([[0.3510737]], dtype=float32))

# %%
predict(X_test[1]), plt.imshow(X_test[1]), preds[1]
# Out:
# ('Natty',
#  <matplotlib.image.AxesImage at 0x7f0c9e4d0310>,
#  array([0.36544347], dtype=float32))

# %%
images_path
# Out:
# ['Angel_Of_Death.jpg',
#  'moi.jpg',
#  'meals.jpg',
#  'Angel_Of_Death_1RAngKg.jpg',
#  'meals_jczglqC.jpg']
